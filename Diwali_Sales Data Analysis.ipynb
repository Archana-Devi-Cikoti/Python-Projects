# %%
#importing libraries
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# data=pd.read_csv("Diwali Sales Data.csv")

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
data=pd.read_csv('Diwali Sales Data.csv',encoding='unicode_escape')

# %%
data.head(10)
# Out:
#    User_ID  Cust_name Product_ID Gender  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F   28               0
# 1  1000732     Kartik  P00110942      F   35               1
# 2  1001990      Bindu  P00118542      F   35               1
# 3  1001425     Sudevi  P00237842      M   16               0
# 4  1000588       Joni  P00057942      M   28               1
# 5  1000588       Joni  P00057942      M   28               1
# 6  1001132       Balk  P00018042      F   25               1
# 7  1002092   Shivangi  P00273442      F   61               0
# 8  1003224     Kushal  P00205642      M   35               0
# 9  1003650      Ginny  P00031142      F   26               1
#
#               State      Zone       Occupation Product_Category  Orders  \
# 0       Maharashtra   Western       Healthcare             Auto       1
# 1    Andhra Pradesh  Southern             Govt             Auto       3
# 2     Uttar Pradesh   Central       Automobile             Auto       3
# ...

# %%
data.shape  #no need to add braces
# Out:
# (11251, 14)

# %%
data.info()  #information about the data, nan values, data types etc
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age               11251 non-null  int64
#  5   Marital_Status    11251 non-null  int64
#  6   State             11251 non-null  object
#  7   Zone              11251 non-null  object
#  8   Occupation        11251 non-null  object
#  9   Product_Category  11251 non-null  object
#  10  Orders            11251 non-null  int64
#  11  Amount            11239 non-null  float64
#  12  Status            0 non-null      float64
#  13  Unnamed           0 non-null      float64
# dtypes: float64(3), int64(4), object(7)
# memory usage: 1.2+ MB

# %%
data.drop(["Status","Unnamed"],axis=1,inplace=True) #droPped 2 rows permanentaly

# %%
data.info()  #prints the various information of the Dataframe such as index type, dtype, columns, non-values, and memory usage
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age               11251 non-null  int64
#  5   Marital_Status    11251 non-null  int64
#  6   State             11251 non-null  object
#  7   Zone              11251 non-null  object
#  8   Occupation        11251 non-null  object
#  9   Product_Category  11251 non-null  object
#  10  Orders            11251 non-null  int64
#  11  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 1.0+ MB

# %%
pd.isnull(data)  #returns a DataFrame object where all the values are replaced with a Boolean value True for NULL values, and otherwise False.
pd.isnull(data).info() #both the above 2 statements are not providing valid info so we use sum
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  bool
#  1   Cust_name         11251 non-null  bool
#  2   Product_ID        11251 non-null  bool
#  3   Gender            11251 non-null  bool
#  4   Age               11251 non-null  bool
#  5   Marital_Status    11251 non-null  bool
#  6   State             11251 non-null  bool
#  7   Zone              11251 non-null  bool
#  8   Occupation        11251 non-null  bool
#  9   Product_Category  11251 non-null  bool
#  10  Orders            11251 non-null  bool
#  11  Amount            11251 non-null  bool
# dtypes: bool(12)
# memory usage: 132.0 KB

# %%
pd.isnull(data).sum() #returns the sum of null values present. there are 12 null values in Amount column
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %% [markdown]
# #### 1.To drop na's since 12 is very negligible value when compared to 11251 rows

# %%
data.dropna(inplace=True) 
#dropping 12 values in amount. 
#if there are NA's in other columns and u only want to drop in particluar column you shoud specify the column name

# %%
pd.isnull(data).sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %% [markdown]
# #### 2.To replace the null values with avgerage of amount

# %%
nullrows=data[data.isnull().any(axis=1)]

# %%
nullrows
# Out:
#      User_ID Cust_name Product_ID Gender  Age  Marital_Status           State  \
# 7    1002092  Shivangi  P00273442      F   61               0     Maharashtra
# 14   1003858      Cano  P00293742      M   46               1  Madhya Pradesh
# 16   1005447       Amy  P00275642      F   48               1  Andhra Pradesh
# 109  1005265    Sakshi  P00296242      F   48               1           Delhi
# 111  1005261   Apoorva  P00057942      F   41               1           Delhi
# 184  1005538    Kartik  P00269542      F   49               1       Karnataka
# 293  1000326  Jonathan  P00120542      M   53               0         Gujarat
# 344  1002507   Lakshmi  P00045842      F   35               1         Gujarat
# 345  1004498   Srishti  P00030842      F   55               0           Delhi
# 452  1004601    Gaurav  P00014442      F   40               1  Madhya Pradesh
# 464  1004528    Anurag  P00338442      F   33               1   Uttar Pradesh
# ...

# %% [markdown]
# #### Grouping the products based on category and filling the missing values by taking the avg of their respective categories

# %%
data['Amount']=data.groupby('Product_Category')['Amount'].transform(lambda x:x.fillna(x.mean()))

# %%
data['Amount'].isnull().sum()
# Out:
# 0

# %%
#cross checking a particular row
check=data[(data["User_ID"]==1005447) & (data['Product_ID']=='P00275642')]
check
#its filled with avg amount of 20191.855567
# Out:
#     User_ID Cust_name Product_ID Gender  Age  Marital_Status           State  \
# 16  1005447       Amy  P00275642      F   48               1  Andhra Pradesh
#
#         Zone Occupation Product_Category  Orders        Amount
# 16  Southern  IT Sector             Auto       3  20191.855567

# %%
pd.isnull(data).sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
#changing the data type of amount. since amount has float value.
data["Amount"]=data["Amount"].astype(int)

# %%
data["Amount"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 11251 entries, 0 to 11250
# Series name: Amount
# Non-Null Count  Dtype
# --------------  -----
# 11251 non-null  int64
# dtypes: int64(1)
# memory usage: 88.0 KB

# %%
data["Amount"].head()
# Out:
# 0    23952
# 1    23934
# 2    23924
# 3    23912
# 4    23877
# Name: Amount, dtype: int64

# %%
data["Amount"].dtypes
# Out:
# dtype('int64')

# %% [markdown]
# the steps needs to follow comes with hands on exp

# %%
data.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age', 'Marital_Status',
#        'State', 'Zone', 'Occupation', 'Product_Category', 'Orders', 'Amount'],
#       dtype='object')

# %%
data.rename(columns={'Marital_Status':'Married'})
# Out:
#        User_ID    Cust_name Product_ID Gender  Age  Married           State  \
# 0      1002903    Sanskriti  P00125942      F   28        0     Maharashtra
# 1      1000732       Kartik  P00110942      F   35        1  Andhra Pradesh
# 2      1001990        Bindu  P00118542      F   35        1   Uttar Pradesh
# 3      1001425       Sudevi  P00237842      M   16        0       Karnataka
# 4      1000588         Joni  P00057942      M   28        1         Gujarat
# ...        ...          ...        ...    ...  ...      ...             ...
# 11246  1000695      Manning  P00296942      M   19        1     Maharashtra
# 11247  1004089  Reichenbach  P00171342      M   33        0         Haryana
# 11248  1001209        Oshin  P00201342      F   40        0  Madhya Pradesh
# 11249  1004023       Noonan  P00059442      M   37        0       Karnataka
# 11250  1002744      Brumley  P00281742      F   19        0     Maharashtra
#
# ...

# %%
#describe returns the statistical information
data.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.125100e+04  11251.000000    11251.000000  11251.000000  11251.000000
# mean   1.003004e+06     35.421207        0.420318      2.489290   9460.454626
# std    1.716125e+03     12.754122        0.493632      1.115047   5224.434220
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      1.500000   5443.500000
# 50%    1.003065e+06     33.000000        0.000000      2.000000   8110.000000
# 75%    1.004430e+06     43.000000        1.000000      3.000000  12691.500000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
data[["Age","Orders","Amount"]].describe() #checking the statiscal values of the relavant columns
# Out:
#                 Age        Orders        Amount
# count  11251.000000  11251.000000  11251.000000
# mean      35.421207      2.489290   9460.454626
# std       12.754122      1.115047   5224.434220
# min       12.000000      1.000000    188.000000
# 25%       27.000000      1.500000   5443.500000
# 50%       33.000000      2.000000   8110.000000
# 75%       43.000000      3.000000  12691.500000
# max       92.000000      4.000000  23952.000000

# %% [markdown]
# ### DATA TRANSFORMATION

# %% [markdown]
# #### Categoring age : since the age has many values starting from min of 12 to max of 92, inorder to reduce the complexity,we are categoringing into groups

# %%
def cat_age(age):
    if age<=17:
        return "0-17"
    elif age<=25:
        return "18-25"
    elif age<=35:
        return "26-35"
    elif age<=45:
        return "36-45"
    elif age<=50:
        return "46-50"
    elif age<=55:
        return "51-55"
    else:
        return "55+"
    
data["Age_group"]=data["Age"].apply(cat_age)

# %%
data.head()
# Out:
#    User_ID  Cust_name Product_ID Gender  Age  Marital_Status           State  \
# 0  1002903  Sanskriti  P00125942      F   28               0     Maharashtra
# 1  1000732     Kartik  P00110942      F   35               1  Andhra Pradesh
# 2  1001990      Bindu  P00118542      F   35               1   Uttar Pradesh
# 3  1001425     Sudevi  P00237842      M   16               0       Karnataka
# 4  1000588       Joni  P00057942      M   28               1         Gujarat
#
#        Zone       Occupation Product_Category  Orders  Amount Age_group
# 0   Western       Healthcare             Auto       1   23952     26-35
# 1  Southern             Govt             Auto       3   23934     26-35
# 2   Central       Automobile             Auto       3   23924     26-35
# 3  Southern     Construction             Auto       2   23912      0-17
# 4   Western  Food Processing             Auto       2   23877     26-35

# %% [markdown]
# ### EDA - EXPLORATORY DATA ANALYSIS

# %%
data.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age', 'Marital_Status',
#        'State', 'Zone', 'Occupation', 'Product_Category', 'Orders', 'Amount',
#        'Age_group'],
#       dtype='object')

# %% [markdown]
# #### GENDER

# %%
ax=sns.countplot(x="Gender",data=data)
for bars in ax.containers: #function to show the count of bars
    ax.bar_label(bars)

# %% [markdown]
# from the above graph, its clear that females have made more orders compared to males, but we also need to know the amount, since females might have spend less ,eventhough the order count is more, so we are grouping by amount

# %%
#graph for gender vs amount spent
sales=data.groupby(['Gender'],as_index=False)['Amount'].sum()#.sort_values(by='Amount',ascending=False)
bx=sns.barplot(x='Gender',y='Amount',data=sales)
for bars in bx.containers:
    bx.bar_label(bars)

#sorting is not making any diff here, so I removed

# %%
sales
# Out:
#   Gender    Amount
# 0      F  74491401
# 1      M  31948174

# %% [markdown]
# #### AGE

# %%
ax1=sns.countplot(x="Age_group",data=data,hue="Gender") #for a count plot we only use Xaxis , 
                                                        #since on Y there will be count. Hue is used to differntiate
for bars in ax1.containers:
    ax1.bar_label(bars)

# %%
sales_by_age=data.groupby(["Age_group"],as_index=False)["Amount"].sum().sort_values(by='Amount',ascending=False)

# %%
sales_by_age
# Out:
#   Age_group    Amount
# 0      0-17   2699653
# 1     18-25  17240732
# 2     26-35  42881671
# 3     36-45  21947810
# 4     46-50   9277640
# 5     51-55   8290891
# 6       55+   4101178

# %%
bx1=sns.barplot(x='Age_group',y='Amount',data=sales_by_age)
for bars in bx1.containers:
    bx1.bar_label(bars)
    
    #when analysing any data, dont just rely on count, also find the purchasing power

# %% [markdown]
# #### STATE

# %%
#total number of orders from top 10 states
sales_states=data.groupby(['State'],as_index=False)['Orders'].sum().sort_values(by='Orders',ascending=False)
sns.set(rc={'figure.figsize':(20,8)})
cx= sns.barplot(x='State',y='Orders',data=sales_states.head()) #checking for top 5
for bars in cx.containers:
    cx.bar_label(bars)

# %%
data.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age', 'Marital_Status',
#        'State', 'Zone', 'Occupation', 'Product_Category', 'Orders', 'Amount',
#        'Age_group'],
#       dtype='object')

# %%
sales_states.head()
# Out:
#              State  Orders
# 14   Uttar Pradesh    4813
# 10     Maharashtra    3811
# 7        Karnataka    3241
# 2            Delhi    2744
# 9   Madhya Pradesh    2259

# %%
#above was sales by amount in states
sales_state_amount=data.groupby(["State"],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)

# %%
sns.set(rc={'figure.figsize':(18,5)})
cx1=sns.barplot(x="State",y='Amount',data=sales_state_amount.head()) #checking for top 5
for bars in cx1.containers:
    cx1.bar_label(bars)

# %%
sales_state_amount
# Out:
#                State    Amount
# 14     Uttar Pradesh  19402224
# 10       Maharashtra  14447734
# 7          Karnataka  13538247
# 2              Delhi  11647939
# 9     Madhya Pradesh   8134961
# 0     Andhra Pradesh   8057337
# 5   Himachal Pradesh   4963368
# 4            Haryana   4220175
# 1              Bihar   4022757
# 3            Gujarat   3976243

# %%
sales_states
# Out:
#                State  Orders
# 14     Uttar Pradesh    4813
# 10       Maharashtra    3811
# 7          Karnataka    3241
# 2              Delhi    2744
# 9     Madhya Pradesh    2259
# 0     Andhra Pradesh    2054
# 5   Himachal Pradesh    1568
# 8             Kerala    1137
# 4            Haryana    1109
# 3            Gujarat    1070

# %% [markdown]
# #### Marital Status

# %%
dx=sns.countplot(x='Marital_Status',data=data)
for bars in dx.containers:
   dx.bar_label(bars)

# %%
data.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age', 'Marital_Status',
#        'State', 'Zone', 'Occupation', 'Product_Category', 'Orders', 'Amount',
#        'Age_group'],
#       dtype='object')

# %%
sales_MS=data.groupby(['Marital_Status','Gender'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
sales_MS
dx1=sns.barplot(x='Marital_Status',y='Amount',hue="Gender",data=sales_MS)
sns.set(rc={'figure.figsize':(5,6)})
for bars in dx1.containers:
   dx1.bar_label(bars)

# %%
data.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age', 'Marital_Status',
#        'State', 'Zone', 'Occupation', 'Product_Category', 'Orders', 'Amount',
#        'Age_group'],
#       dtype='object')

# %% [markdown]
# #### OCCUPATION

# %%
ex=sns.countplot(x='Occupation',data=data,hue='Gender')
sns.set(rc={'figure.figsize':(16,10)})
for bars in ex.containers:
    ex.bar_label(bars)

# %%
sales_ocup=data.groupby(['Occupation',"Gender"],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False).head(10)

# %%
sales_ocup
# Out:
#      Occupation Gender    Amount
# 20    IT Sector      F  10253552
# 4      Aviation      F   9007393
# 16   Healthcare      F   8968231
# 6       Banking      F   7821709
# 14         Govt      F   6002907
# 21    IT Sector      M   4584951
# 24        Media      F   4375029
# 18  Hospitality      F   4196827
# 17   Healthcare      M   4066355
# 2    Automobile      F   3782471

# %%
ex1=sns.barplot(x='Occupation',y='Amount',data=sales_ocup,hue='Gender')
for bars in ex1.containers:
    ex1.bar_label(bars)

# %% [markdown]
# #### PRODUCT CATEGORY

# %%
data.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age', 'Marital_Status',
#        'State', 'Zone', 'Occupation', 'Product_Category', 'Orders', 'Amount',
#        'Age_group'],
#       dtype='object')

# %%
fx=sns.countplot(x='Product_Category',data=data)
sns.set(rc={'figure.figsize':(16,15)})
for bars in fx.containers:
    fx.bar_label(bars)
#clothing category order count is more, next is food

# %%
sales_prod=data.groupby(["Product_Category"],as_index=False)["Amount"].sum().sort_values(by='Amount',ascending=False).head(10)

# %%
sales_prod
# Out:
#          Product_Category    Amount
# 6                    Food  33974767
# 3      Clothing & Apparel  16495019
# 7        Footwear & Shoes  15648744
# 5   Electronics & Gadgets  15643846
# 8               Furniture   5455505
# 9            Games & Toys   4331694
# 14        Sports Products   3635933
# 0                    Auto   2019182
# 1                  Beauty   1959484
# 15             Stationery   1676051

# %%
fx1=sns.barplot(x="Product_Category",y="Amount",data=sales_occup)

# %% [markdown]
# though the cloting category had more number of orders count, when amount is analyised, food category sales amount is hue this is one of the examples that we shouldnt always rely on count and predict the behaviour

# %% [markdown]
# #### PRODUCT ID

# %%
gx=sns.countplot(x='Product_ID',data=data,hue="orders")
for bars in gx.containers:
    gx.bar_label(bars)

# %%
data.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age', 'Marital_Status',
#        'State', 'Zone', 'Occupation', 'Product_Category', 'Orders', 'Amount',
#        'Age_group'],
#       dtype='object')

# %%
sale_P_id=data.groupby(["Product_ID",'Orders'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)

# %%
sale_P_id
# Out:
#      Product_ID  Orders  Amount
# 1519  P00112142       1  181504
# 1482  P00110942       3  160926
# 4006  P00265242       4  155297
# 2775  P00184942       1  150290
# 4003  P00265242       1  144904
# ...         ...     ...     ...
# 4626  P00307142       1     572
# 683   P00044742       1     396
# 4484  P00296942       4     370
# 2501  P00171342       3     367
# 4255  P00281742       3     188
#
# [5526 rows x 3 columns]

# %%
sale_P_id_amount=data.groupby(["Product_ID",],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False).head(5)

# %%
sale_P_id_amount
# Out:
#      Product_ID  Amount
# 1680  P00265242  540136
# 645   P00110942  424833
# 1147  P00184942  401816
# 655   P00112142  341020
# 397   P00059442  338571

# %%
gx1=sns.barplot(x='Product_ID',y='Amount',data=sale_P_id_amount)
sns.set(rc={'figure.figsize':(1,9)})
for bars in gx1.containers:
    gx1.bar_label(bars)

# %%
sale_P_id_orders=data.groupby(["Product_ID",],as_index=False)['Orders'].sum().sort_values(by='Orders',ascending=False).head(5)

# %%
sale_P_id_orders
# Out:
#      Product_ID  Orders
# 1680  P00265242     127
# 645   P00110942     116
# 1505  P00237542      91
# 1147  P00184942      82
# 680   P00114942      79

# %%
gx2=sns.barplot(x='Product_ID',y='Orders',data=sale_P_id_orders)
sns.set(rc={'figure.figsize':(1,9)})
for bars in gx2.containers:
    gx2.bar_label(bars)

# %% [markdown]
# Conclusion:
# Married women age group 26-35 yrs from UP, Maharastra and Karnataka working in IT, Healthcare and Aviation are more likely to buy products from Food, Clothing and Electronics category
#
# Thank you!
